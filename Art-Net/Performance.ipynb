# %%
import numpy as np 
import os
import glob
import cv2
import glob
import itertools
from skimage.morphology import skeletonize
import skimage.io as io
import skimage.transform as trans
import matplotlib.pyplot as plt
from math import atan2,degrees, atan
from mpl_toolkits.mplot3d import Axes3D
from skimage.morphology import skeletonize
from skimage.transform import hough_line, hough_line_peaks, probabilistic_hough_line
from matplotlib import cm
from shapely.geometry import LineString
from shapely.geometry import Point
from sympy import *
import math
from sympy.geometry import *
from skimage.measure import label, regionprops
from scipy.spatial import distance
from skimage.morphology import disk
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
#from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import precision_score, accuracy_score, roc_curve, auc

# %%
def Angular_Displacement(height, width, L1x1, L1y1, L1x2, L1y2, L2x1, L2y1, L2x2, L2y2):
    '''
    This code is for calculating Angular Displacement between a pair of lines.
    The predicted edge and mid line features can be evaluated quantitatively using the mean angular 
    displacement (mAD) error from the center of the image frame between the true andpredicted line.
    Angular displacement is calculated by the arc length distance between true point and predicted point.
    More details explanations of this metric see the paper please. 
    
    Input Arguments: 
        height = Height of the Image
        width  = Width of the Image
        L1x1 =  Initial X co-ordinate of the first line
        L1y1 =  Initial Y co-ordinate of the first line
        L1x2 =  Final X co-ordinate of the first line
        L1y2 =  Final Y co-ordinate of the first line
        L2x1 =  Initial X co-ordinate of the second line
        L2y1 =  Initial Y co-ordinate of the second line
        L2x2 =  Final X co-ordinate of the second line
        L2y2 =  Final Y co-ordinate of the second line
        
    Output Arguments:  
    
        AngularDisplacement: The average Angular Displacement of left and right side Displacement.
        
    Author: Md. Kamrul Hasan, 
        Erasmus Scholar on Medical Imaging and Application (MAIA)
        E-mail: kamruleeekuet@gmail.com
        
    '''

    center_x = int(height/2)
    center_y = int(width/2)
    centerPoint = Point(center_x,center_y)
    radius = np.sqrt((center_x)**2+(center_y)**2)

    circle = Circle(centerPoint, radius)

    lineApprox = Line((L1x1,L1y1),(L1x2,L1y2))
    lineTrue = Line((L2x1,L2y1),(L2x2,L2y2))

    intersectionApprox= intersection(circle, lineApprox)
    intersectionTrue= intersection(circle, lineTrue)

    intXY1P = intersectionApprox[0].evalf()
    X_P_1 = intXY1P.x
    Y_P_1 = intXY1P.y
#         print(X_P_1)
#         print(Y_P_1)

    intXY2P = intersectionApprox[1].evalf()
    X_P_2 = intXY2P.x
    Y_P_2 = intXY2P.y
#         print(X_P_2)
#         print(Y_P_2)


    intXY1G = intersectionTrue[0].evalf()
    X_G_1 = intXY1G.x
    Y_G_1 = intXY1G.y
#         print(X_G_1)
#         print(Y_G_1)


    intXY2G = intersectionTrue[1].evalf()
    X_G_2 = intXY2G.x
    Y_G_2 = intXY2G.y
#         print(X_G_2)
#         print(Y_G_2)

    slope1_P, intercept=slope_intercept(X_P_1, Y_P_1, center_x, center_y)
    slope1_G, intercept=slope_intercept(X_G_1, Y_G_1, center_x, center_y)

    slope2_P, intercept=slope_intercept(X_P_2, Y_P_2, center_x, center_y)
    slope2_G, intercept=slope_intercept(X_G_2, Y_G_2, center_x, center_y)

#         print(slope1_P)
#         print(slope1_G)
#         print(slope2_P)
#         print(slope2_G)

    theta_1=atan(abs((slope1_P-slope1_G)/(1+slope1_G*slope1_P)))
    theta_2=atan(abs((slope2_P-slope2_G)/(1+slope2_G*slope2_P)))
    
    AngularDisplacement=(theta_1+theta_2)/2
    
    return AngularDisplacement



def Performance_Metrics(y_true, y_pred):
    ''' 
    The Dice similarity coefficient (DSC) is a statistical validation metric for the image
    segmentations and determines the spatial overlap accuracy of the segmentation. It also 
    same as F1-score. 
    
    The Intersection over Union (IoU) also referred to as the Jaccard index (JI), is essentially
    a method to quantify the percent overlap between the GT mask and prediction output.
    This metric is closely related to the DSC. The IoU metric measures the number of pixels
    common between the target and prediction masks divided by the total number of pixels present
    across both masks.
    
    Mathematically, they are related as follows:
    IoU = DSC/(2-DSC) or DSC = 2*IoU/(IoU+1)
    
    The Sensitivity also called the true positive rate, the recall, or probability of detection that 
    measures the proportion of actual positives that are correctly identified as such class 
    (e.g., the percentage of sick people who are correctly identified as having the condition).
    
    The Specificity also called the true negative rate measures the proportion of actual negatives that
    are correctly identified as such class. (e.g., the percentage of healthy people who are correctly
    identified as not having the condition).
    
  
    Input Arguments: 
        y_true: True Labels of the 2D images so called ground truth (GT).
        y_pred: Predicted Labels of the 2D images so called Predicted/ segmented Mask.
        
    Output Arguments: 
        dsc: The DSC between y_true and y_pred
        iou: The IoU between y_true and y_pred
        accuracy: The accuracy of pixels clasification.
        sensitivity: The accuracy of foreground pixels clasification.
        specificity: The accuracy of background pixels clasification.
        balancedAccuracy: The balanced accuracy of both foreground & background pixels clasification.
        
    Author: Md. Kamrul Hasan, 
            Erasmus Scholar on Medical Imaging and Application (MAIA)
            E-mail: kamruleeekuet@gmail.com

    '''
    if y_true.shape != y_pred.shape:
        raise ValueError("Shape mismatch!! y_true and y_pred must have the same shape.")

    y_true_f = (y_true/y_true.max()).flatten()
    y_pred_f = (y_pred/y_pred.max()).flatten()
    
    intersection = np.sum(y_true_f * y_pred_f)
    
    dsc = (2. * intersection ) / (np.sum(y_true_f) + np.sum(y_pred_f))
    iou = (intersection) / (np.sum(y_true_f) + np.sum(y_pred_f)-intersection)
    
    y_true = np.asarray(y_true).astype(np.bool)
    y_pred = np.asarray(y_pred).astype(np.bool)

        
    y_true=y_true.flatten()
    y_pred=y_pred.flatten()
    
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    accuracy = (tn+tp)/(tn+fp+fn+tp)
    sensitivity = (tp)/(fn+tp)
    specificity = (tn)/(tn+fp)
    balancedAccuracy = (sensitivity+specificity)/2

    
    return dsc, iou, accuracy, sensitivity, specificity, balancedAccuracy



def slope_intercept(xi, yi, xf, yf):
    '''
    This function is dedicated for calculating the slope of the line. 
    
    Input Arguments: 
         xi: The initial X co-ordinate
         yi: The initial Y co-ordinate
         xf: The final X co-ordinate
         yf: The final Y co-ordinate
         
    Output Arguments:
        slope: Slope of the st. line connecting those two points
        intercept: The intersecting length from Y-axis
         
    Author: Md. Kamrul Hasan, 
        Erasmus Scholar on Medical Imaging and Application (MAIA)
        E-mail: kamruleeekuet@gmail.com
        
    '''
    
    slope = (yf - yi) / (xf - xi)
    intercept = yi - slope * xi 
    
    return slope,intercept

# %% [markdown]
# ## Evaluate Segmentation

# %%
CurrentDirectory=os.getcwd()
PredictionPath = '/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/'
Prediction = glob.glob(PredictionPath+"*.png")
Prediction.sort()
# print(len(Prediction))

OriginalmaskGT = glob.glob('/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Test_Positive_Tool_Mask/'+"*.png")
OriginalmaskGT.sort()
# print(len(OriginalmaskGT))

OriginalImage = glob.glob('/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Test_Positive/'+"*.png")
OriginalImage.sort()
# print(len(OriginalImage))

masksavePath = '/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Results_Evaluation/Tool_Mask/'

i=0

dice=[]
sensitivity=[]
specificity=[]
accuracy = []
BalancedAccuracy=[]
IoU=[]

for Pred in Prediction:
    
    filename, file_extension = os.path.splitext(Pred) 
    if 'tool_mask' in filename:
        print(filename)
        #----------------------------------Read the Prediction from SIMO------------------------------
        imgPred = cv2.imread(Pred,0)
        
        # Apply the threshold since output was sigmoid activations of segmentation sub-network
        threshold = 30
        imgPred[imgPred<threshold] = 0
        imgPred[imgPred>=threshold] = 255
        
        #--------------------------------Read Original Image with Mask GT----------------------------
        orimg = cv2.imread(OriginalImage[i],-1)
        orimg = cv2.resize(orimg,(256,192))
        
        truemask = cv2.imread(OriginalmaskGT[i],0)
        truemask = cv2.resize(truemask,(256,192))
        i=i+1
        
        #-------------------------------Overlay with original Image------------------------------------       
        temp = cv2.merge((imgPred, imgPred, imgPred))
        temp [:,:,0]=0
        temp [:,:,2]=0       

        overlay = cv2.addWeighted(temp, 0.5, orimg, 0.8, 0)
        
     
        # Call the Performance Evaluation functions by passing predicted and true mask
        dsc, iou, acc, sen, spe, bAcc = Performance_Metrics(imgPred, truemask)

        dice.append(dsc)
        IoU.append(iou)
        accuracy.append(acc)
        sensitivity.append(sen)
        specificity.append(spe)
        BalancedAccuracy.append(bAcc)
        
        font                   = cv2.FONT_HERSHEY_SIMPLEX
        bottomLeftCornerOfText = (80,185)
        fontScale              = 1
        fontColor              = (255,255,255)
        lineType               = 2
        

        cv2.putText(overlay, str(round(dsc,4)), 
            bottomLeftCornerOfText, 
            font, 
            fontScale,
            fontColor,
            lineType)
        
        savelinePath=masksavePath+'ImgID_'+filename[-14:]+'_Overlay_with_OrgImg.png'
        cv2.imwrite(savelinePath, overlay)  
        print('ImageID: '+ filename[-12]+'. Dice co-efficient: '+ str(dsc)
              + '  Balanced Accuracy: ' + str(bAcc))
        
print()
print('-----------------------Final Segmentation metrics are as follows:---------------------------')
print("DSC = %0.4f (+/-%0.04f)" % (np.mean(dice)*100, np.std(dice)*100))
print("Sensitivity = %0.4f (+/-%0.04f)" % (np.mean(sensitivity)*100, np.std(sensitivity)*100))
print("Specificity = %0.4f (+/-%0.04f)" % (np.mean(specificity)*100, np.std(specificity)*100))
print("Accuracy = %0.8f (+/-%0.04f)" % (np.mean(accuracy)*100, np.std(accuracy)*100))
print("IoU = %0.4f (+/-%0.04f)" % (np.mean(IoU)*100, np.std(IoU)*100))
print("Balanced Accuracy = %0.4f (+/-%0.04f)" % (np.mean(BalancedAccuracy)*100, np.std(BalancedAccuracy)*100))
# Out:
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0001_tool_mask
# ImageID: 0. Dice co-efficient: 0.9097617672376123  Balanced Accuracy: 0.9463016270628422
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0002_tool_mask
# ImageID: 0. Dice co-efficient: 0.926805203647147  Balanced Accuracy: 0.9402082292098479
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0003_tool_mask
# ImageID: 0. Dice co-efficient: 0.9714187742069672  Balanced Accuracy: 0.9849306379234262
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0004_tool_mask
# ImageID: 0. Dice co-efficient: 0.9807261960178959  Balanced Accuracy: 0.9858891866051623
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0005_tool_mask
# ImageID: 0. Dice co-efficient: 0.9756490342109849  Balanced Accuracy: 0.9820466701708994
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0006_tool_mask
# ImageID: 0. Dice co-efficient: 0.9593577723402862  Balanced Accuracy: 0.9692163438038537
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0007_tool_mask
# ImageID: 0. Dice co-efficient: 0.974029907316719  Balanced Accuracy: 0.9815644481203238
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0008_tool_mask
# ImageID: 0. Dice co-efficient: 0.9529482476779896  Balanced Accuracy: 0.9603126507213382
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0009_tool_mask
# ImageID: 0. Dice co-efficient: 0.9276268110628617  Balanced Accuracy: 0.9472487339108194
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0010_tool_mask
# ImageID: 1. Dice co-efficient: 0.8362672140065107  Balanced Accuracy: 0.8770648464847983
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0011_tool_mask
# ImageID: 1. Dice co-efficient: 0.962291912259834  Balanced Accuracy: 0.9765068473874399
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0012_tool_mask
# ImageID: 1. Dice co-efficient: 0.9464257445363923  Balanced Accuracy: 0.9607729556464146
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0013_tool_mask
# ImageID: 1. Dice co-efficient: 0.9604645489086464  Balanced Accuracy: 0.971364646709197
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0014_tool_mask
# ImageID: 1. Dice co-efficient: 0.8685724605658625  Balanced Accuracy: 0.9771424845912355
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0015_tool_mask
# ImageID: 1. Dice co-efficient: 0.9670050020091409  Balanced Accuracy: 0.9905247370738232
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0016_tool_mask
# ImageID: 1. Dice co-efficient: 0.9739735468107247  Balanced Accuracy: 0.9844008386091321
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0017_tool_mask
# ImageID: 1. Dice co-efficient: 0.9653518579818224  Balanced Accuracy: 0.9827048391269562
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0018_tool_mask
# ImageID: 1. Dice co-efficient: 0.9594742850587564  Balanced Accuracy: 0.98475146462271
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0019_tool_mask
# ImageID: 1. Dice co-efficient: 0.9113845939663825  Balanced Accuracy: 0.9357016729479595
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0020_tool_mask
# ImageID: 2. Dice co-efficient: 0.8987659405026771  Balanced Accuracy: 0.9536477432878696
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0021_tool_mask
# ImageID: 2. Dice co-efficient: 0.94591358480941  Balanced Accuracy: 0.9763955052042701
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0022_tool_mask
# ImageID: 2. Dice co-efficient: 0.9470675149165239  Balanced Accuracy: 0.9653068208308875
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0023_tool_mask
# ImageID: 2. Dice co-efficient: 0.8980627024384281  Balanced Accuracy: 0.9668537400565174
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0024_tool_mask
# ImageID: 2. Dice co-efficient: 0.9713637724869779  Balanced Accuracy: 0.9804407643467146
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0025_tool_mask
# ImageID: 2. Dice co-efficient: 0.9588886534784911  Balanced Accuracy: 0.9809567211644182
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0026_tool_mask
# ImageID: 2. Dice co-efficient: 0.9598008311427666  Balanced Accuracy: 0.9796517308427726
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0027_tool_mask
# ImageID: 2. Dice co-efficient: 0.9181964306216432  Balanced Accuracy: 0.9472618825782673
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0028_tool_mask
# ImageID: 2. Dice co-efficient: 0.8823838552514682  Balanced Accuracy: 0.9033467726032698
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0029_tool_mask
# ImageID: 2. Dice co-efficient: 0.9249237679570012  Balanced Accuracy: 0.9603006398132727
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0030_tool_mask
# ImageID: 3. Dice co-efficient: 0.9562504452828188  Balanced Accuracy: 0.9660951866294156
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0031_tool_mask
# ImageID: 3. Dice co-efficient: 0.9116719242902209  Balanced Accuracy: 0.9230899684203631
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0032_tool_mask
# ImageID: 3. Dice co-efficient: 0.9278730612914843  Balanced Accuracy: 0.95694905983093
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0033_tool_mask
# ImageID: 3. Dice co-efficient: 0.9727983088542174  Balanced Accuracy: 0.9868185346434446
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0034_tool_mask
# ImageID: 3. Dice co-efficient: 0.9440421797732025  Balanced Accuracy: 0.9781897311769714
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0035_tool_mask
# ImageID: 3. Dice co-efficient: 0.9498901537729033  Balanced Accuracy: 0.972599564576962
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0036_tool_mask
# ImageID: 3. Dice co-efficient: 0.9761511021275455  Balanced Accuracy: 0.9862160005510536
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0037_tool_mask
# ImageID: 3. Dice co-efficient: 0.9661812010465936  Balanced Accuracy: 0.9757390934034733
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0038_tool_mask
# ImageID: 3. Dice co-efficient: 0.9744275155994427  Balanced Accuracy: 0.978629644244779
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0039_tool_mask
# ImageID: 3. Dice co-efficient: 0.9801147741094941  Balanced Accuracy: 0.9895173208204477
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0040_tool_mask
# ImageID: 4. Dice co-efficient: 0.9383602429521753  Balanced Accuracy: 0.9820409044417157
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0041_tool_mask
# ImageID: 4. Dice co-efficient: 0.9474718245149242  Balanced Accuracy: 0.9771053949212234
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0042_tool_mask
# ImageID: 4. Dice co-efficient: 0.9699535395379815  Balanced Accuracy: 0.9812204498106197
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0043_tool_mask
# ImageID: 4. Dice co-efficient: 0.922155342448047  Balanced Accuracy: 0.9687749019196819
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0044_tool_mask
# ImageID: 4. Dice co-efficient: 0.9523035456803176  Balanced Accuracy: 0.9744375592931189
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0045_tool_mask
# ImageID: 4. Dice co-efficient: 0.9398169828753685  Balanced Accuracy: 0.9581830237658526
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0046_tool_mask
# ImageID: 4. Dice co-efficient: 0.940837994537993  Balanced Accuracy: 0.9658141911309641
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0047_tool_mask
# ImageID: 4. Dice co-efficient: 0.9777484772436148  Balanced Accuracy: 0.988675347849707
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0048_tool_mask
# ImageID: 4. Dice co-efficient: 0.9723480968797349  Balanced Accuracy: 0.9842082400236197
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0049_tool_mask
# ImageID: 4. Dice co-efficient: 0.9521963789360504  Balanced Accuracy: 0.9761266333964602
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0050_tool_mask
# ImageID: 5. Dice co-efficient: 0.9580682611052308  Balanced Accuracy: 0.9717191820256255
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0051_tool_mask
# ImageID: 5. Dice co-efficient: 0.9556530396624612  Balanced Accuracy: 0.9668012283344527
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0052_tool_mask
# ImageID: 5. Dice co-efficient: 0.91577001828249  Balanced Accuracy: 0.9582130067512743
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0053_tool_mask
# ImageID: 5. Dice co-efficient: 0.9714228171557083  Balanced Accuracy: 0.9789751353525649
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0054_tool_mask
# ImageID: 5. Dice co-efficient: 0.964186252056277  Balanced Accuracy: 0.9750591967062534
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0055_tool_mask
# ImageID: 5. Dice co-efficient: 0.9393068427153872  Balanced Accuracy: 0.9462694009993051
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0056_tool_mask
# ImageID: 5. Dice co-efficient: 0.946668096813189  Balanced Accuracy: 0.960105538081407
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0057_tool_mask
# ImageID: 5. Dice co-efficient: 0.9609437967515613  Balanced Accuracy: 0.9898892537386855
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0058_tool_mask
# ImageID: 5. Dice co-efficient: 0.9464411673644733  Balanced Accuracy: 0.951353188158218
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0059_tool_mask
# ImageID: 5. Dice co-efficient: 0.9727586509304211  Balanced Accuracy: 0.9776594683074707
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0060_tool_mask
# ImageID: 6. Dice co-efficient: 0.9501853396456462  Balanced Accuracy: 0.9855299125768885
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0061_tool_mask
# ImageID: 6. Dice co-efficient: 0.9306709360934745  Balanced Accuracy: 0.9609524413011025
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0062_tool_mask
# ImageID: 6. Dice co-efficient: 0.9035051231516046  Balanced Accuracy: 0.919174051405575
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0063_tool_mask
# ImageID: 6. Dice co-efficient: 0.9396289323635102  Balanced Accuracy: 0.9522246536269767
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0064_tool_mask
# ImageID: 6. Dice co-efficient: 0.9510311781389246  Balanced Accuracy: 0.9746544563936081
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0065_tool_mask
# ImageID: 6. Dice co-efficient: 0.9565482143667997  Balanced Accuracy: 0.9764373366897383
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0066_tool_mask
# ImageID: 6. Dice co-efficient: 0.9693061120820429  Balanced Accuracy: 0.9826542128691489
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0067_tool_mask
# ImageID: 6. Dice co-efficient: 0.8785691826253613  Balanced Accuracy: 0.9672163167733777
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0068_tool_mask
# ImageID: 6. Dice co-efficient: 0.9419402285865249  Balanced Accuracy: 0.9544611084236387
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0069_tool_mask
# ImageID: 6. Dice co-efficient: 0.8929174244929453  Balanced Accuracy: 0.9622387660899332
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0070_tool_mask
# ImageID: 7. Dice co-efficient: 0.9483335955009551  Balanced Accuracy: 0.9738845271912957
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0071_tool_mask
# ImageID: 7. Dice co-efficient: 0.9379594972199417  Balanced Accuracy: 0.9606105508795091
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0072_tool_mask
# ImageID: 7. Dice co-efficient: 0.9102644490952698  Balanced Accuracy: 0.9376380626623517
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0073_tool_mask
# ImageID: 7. Dice co-efficient: 0.9296696484983985  Balanced Accuracy: 0.9576716424318663
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0074_tool_mask
# ImageID: 7. Dice co-efficient: 0.9221025431979575  Balanced Accuracy: 0.9402746953003274
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0075_tool_mask
# ImageID: 7. Dice co-efficient: 0.9440907099736  Balanced Accuracy: 0.9697853200741253
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0076_tool_mask
# ImageID: 7. Dice co-efficient: 0.9470206506257993  Balanced Accuracy: 0.9752889992807885
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0077_tool_mask
# ImageID: 7. Dice co-efficient: 0.97534774035491  Balanced Accuracy: 0.9830216877730942
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0078_tool_mask
# ImageID: 7. Dice co-efficient: 0.9552552957596295  Balanced Accuracy: 0.9748306524397821
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0079_tool_mask
# ImageID: 7. Dice co-efficient: 0.901577557453887  Balanced Accuracy: 0.9676209374848546
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0080_tool_mask
# ImageID: 8. Dice co-efficient: 0.9384225352841022  Balanced Accuracy: 0.9569044629057186
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0081_tool_mask
# ImageID: 8. Dice co-efficient: 0.828864840147849  Balanced Accuracy: 0.9424726835487026
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0082_tool_mask
# ImageID: 8. Dice co-efficient: 0.9383741428241267  Balanced Accuracy: 0.9575104266140384
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0083_tool_mask
# ImageID: 8. Dice co-efficient: 0.9214932803072449  Balanced Accuracy: 0.9334872131740004
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0084_tool_mask
# ImageID: 8. Dice co-efficient: 0.965568272455579  Balanced Accuracy: 0.9822264414374773
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0085_tool_mask
# ImageID: 8. Dice co-efficient: 0.8843450028997761  Balanced Accuracy: 0.9175884731540223
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0086_tool_mask
# ImageID: 8. Dice co-efficient: 0.8861210830742066  Balanced Accuracy: 0.9219932860520308
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0087_tool_mask
# ImageID: 8. Dice co-efficient: 0.9324464011693763  Balanced Accuracy: 0.9451932002101211
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0088_tool_mask
# ImageID: 8. Dice co-efficient: 0.911839495761477  Balanced Accuracy: 0.9232776098123181
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0089_tool_mask
# ImageID: 8. Dice co-efficient: 0.8601554579249747  Balanced Accuracy: 0.8853627100173029
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0090_tool_mask
# ImageID: 9. Dice co-efficient: 0.9576813300803186  Balanced Accuracy: 0.9668859481530758
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0091_tool_mask
# ImageID: 9. Dice co-efficient: 0.9422038613297253  Balanced Accuracy: 0.9615271404419756
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0092_tool_mask
# ImageID: 9. Dice co-efficient: 0.9640941866006832  Balanced Accuracy: 0.9737058492790325
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0093_tool_mask
# ImageID: 9. Dice co-efficient: 0.9680528473668991  Balanced Accuracy: 0.9806539909159174
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0094_tool_mask
# ImageID: 9. Dice co-efficient: 0.9660397120345678  Balanced Accuracy: 0.9791871343717995
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0095_tool_mask
# ImageID: 9. Dice co-efficient: 0.9222722560231009  Balanced Accuracy: 0.9630204660077649
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0096_tool_mask
# ImageID: 9. Dice co-efficient: 0.954053384240241  Balanced Accuracy: 0.9718980420437386
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0097_tool_mask
# ImageID: 9. Dice co-efficient: 0.9324377688727223  Balanced Accuracy: 0.9506121258208791
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0098_tool_mask
# ImageID: 9. Dice co-efficient: 0.9589762351449572  Balanced Accuracy: 0.9799703645655984
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0099_tool_mask
# ImageID: 9. Dice co-efficient: 0.6534993445014453  Balanced Accuracy: 0.9463391304180534
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0100_tool_mask
# ImageID: 0. Dice co-efficient: 0.885517066004178  Balanced Accuracy: 0.9155966138273242
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0101_tool_mask
# ImageID: 0. Dice co-efficient: 0.9737013029040652  Balanced Accuracy: 0.9864030480646524
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0102_tool_mask
# ImageID: 0. Dice co-efficient: 0.9364614951804198  Balanced Accuracy: 0.9713450806518074
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0103_tool_mask
# ImageID: 0. Dice co-efficient: 0.966742747276727  Balanced Accuracy: 0.9799966425740696
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0104_tool_mask
# ImageID: 0. Dice co-efficient: 0.9040641623507948  Balanced Accuracy: 0.9252865663964891
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0105_tool_mask
# ImageID: 0. Dice co-efficient: 0.8668899733979364  Balanced Accuracy: 0.9006085119146151
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0106_tool_mask
# ImageID: 0. Dice co-efficient: 0.8859880274036996  Balanced Accuracy: 0.907278977794119
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0107_tool_mask
# ImageID: 0. Dice co-efficient: 0.9609899777792535  Balanced Accuracy: 0.974419209084611
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0108_tool_mask
# ImageID: 0. Dice co-efficient: 0.9714152921166093  Balanced Accuracy: 0.9877637145608846
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0109_tool_mask
# ImageID: 0. Dice co-efficient: 0.9523792774625208  Balanced Accuracy: 0.9716938826023003
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0110_tool_mask
# ImageID: 1. Dice co-efficient: 0.8540627771764085  Balanced Accuracy: 0.8838018164637818
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0111_tool_mask
# ImageID: 1. Dice co-efficient: 0.9329804862061889  Balanced Accuracy: 0.957450277691731
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0112_tool_mask
# ImageID: 1. Dice co-efficient: 0.43027265930619435  Balanced Accuracy: 0.7648080913035726
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0113_tool_mask
# ImageID: 1. Dice co-efficient: 0.9331932929718906  Balanced Accuracy: 0.9855288015381113
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0114_tool_mask
# ImageID: 1. Dice co-efficient: 0.949516428518059  Balanced Accuracy: 0.970285871169487
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0115_tool_mask
# ImageID: 1. Dice co-efficient: 0.9696061146764265  Balanced Accuracy: 0.9845914370381378
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0116_tool_mask
# ImageID: 1. Dice co-efficient: 0.9190942304717846  Balanced Accuracy: 0.9379913836939124
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0117_tool_mask
# ImageID: 1. Dice co-efficient: 0.9220355692591694  Balanced Accuracy: 0.9509421203508772
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0118_tool_mask
# ImageID: 1. Dice co-efficient: 0.8973105530960837  Balanced Accuracy: 0.9286465797192087
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0119_tool_mask
# ImageID: 1. Dice co-efficient: 0.9546480010968514  Balanced Accuracy: 0.9814775483469622
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0120_tool_mask
# ImageID: 2. Dice co-efficient: 0.9678371390225661  Balanced Accuracy: 0.9832857314503713
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0121_tool_mask
# ImageID: 2. Dice co-efficient: 0.9753720145898178  Balanced Accuracy: 0.9955453157249057
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0122_tool_mask
# ImageID: 2. Dice co-efficient: 0.9558850713628616  Balanced Accuracy: 0.9855221437950075
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0123_tool_mask
# ImageID: 2. Dice co-efficient: 0.9666399359809894  Balanced Accuracy: 0.9852617442070585
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0124_tool_mask
# ImageID: 2. Dice co-efficient: 0.9544946123362065  Balanced Accuracy: 0.9809573478439573
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0125_tool_mask
# ImageID: 2. Dice co-efficient: 0.8906829404284083  Balanced Accuracy: 0.9213110197791836
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0126_tool_mask
# ImageID: 2. Dice co-efficient: 0.9623997997114768  Balanced Accuracy: 0.9761182883605874
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0127_tool_mask
# ImageID: 2. Dice co-efficient: 0.9616909057106656  Balanced Accuracy: 0.9753239739784956
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0128_tool_mask
# ImageID: 2. Dice co-efficient: 0.9678762751463971  Balanced Accuracy: 0.9783481167062167
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0129_tool_mask
# ImageID: 2. Dice co-efficient: 0.8969302711096  Balanced Accuracy: 0.9177061951932115
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0130_tool_mask
# ImageID: 3. Dice co-efficient: 0.9611622534846528  Balanced Accuracy: 0.9836397832991355
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0131_tool_mask
# ImageID: 3. Dice co-efficient: 0.9629524644909139  Balanced Accuracy: 0.9927334482319377
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0132_tool_mask
# ImageID: 3. Dice co-efficient: 0.9193613228754849  Balanced Accuracy: 0.9397569443452365
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0133_tool_mask
# ImageID: 3. Dice co-efficient: 0.8059216209328571  Balanced Accuracy: 0.8551632072657704
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0134_tool_mask
# ImageID: 3. Dice co-efficient: 0.9001105001056796  Balanced Accuracy: 0.9881662926895303
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0135_tool_mask
# ImageID: 3. Dice co-efficient: 0.9455311370426722  Balanced Accuracy: 0.962550485705437
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0136_tool_mask
# ImageID: 3. Dice co-efficient: 0.9312974067434044  Balanced Accuracy: 0.9634004724673435
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0137_tool_mask
# ImageID: 3. Dice co-efficient: 0.9578022888134394  Balanced Accuracy: 0.9742765797982542
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0138_tool_mask
# ImageID: 3. Dice co-efficient: 0.8015282033015383  Balanced Accuracy: 0.9817958311325214
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0139_tool_mask
# ImageID: 3. Dice co-efficient: 0.8689851831650123  Balanced Accuracy: 0.9407579323020498
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0140_tool_mask
# ImageID: 4. Dice co-efficient: 0.6215417701102168  Balanced Accuracy: 0.9079406317814631
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0141_tool_mask
# ImageID: 4. Dice co-efficient: 0.9689688553405197  Balanced Accuracy: 0.9805716827182471
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0142_tool_mask
# ImageID: 4. Dice co-efficient: 0.8098594428365651  Balanced Accuracy: 0.8551819834164514
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0143_tool_mask
# ImageID: 4. Dice co-efficient: 0.9449244479162329  Balanced Accuracy: 0.9768383552167336
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0144_tool_mask
# ImageID: 4. Dice co-efficient: 0.9689608436737682  Balanced Accuracy: 0.9892909220388156
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0145_tool_mask
# ImageID: 4. Dice co-efficient: 0.9443273007085252  Balanced Accuracy: 0.9692788936034913
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0146_tool_mask
# ImageID: 4. Dice co-efficient: 0.9539192701647473  Balanced Accuracy: 0.9679455595672104
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0147_tool_mask
# ImageID: 4. Dice co-efficient: 0.938285879271805  Balanced Accuracy: 0.9509975163921776
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0148_tool_mask
# ImageID: 4. Dice co-efficient: 0.9525469821655854  Balanced Accuracy: 0.9686340406153882
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0149_tool_mask
# ImageID: 4. Dice co-efficient: 0.8520448673374404  Balanced Accuracy: 0.8860963732451865
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0150_tool_mask
# ImageID: 5. Dice co-efficient: 0.9308922911925862  Balanced Accuracy: 0.9579191939582112
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0151_tool_mask
# ImageID: 5. Dice co-efficient: 0.9365145153442777  Balanced Accuracy: 0.9723054971933895
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0152_tool_mask
# ImageID: 5. Dice co-efficient: 0.9408945958642313  Balanced Accuracy: 0.9570625415001229
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0153_tool_mask
# ImageID: 5. Dice co-efficient: 0.9367885003601245  Balanced Accuracy: 0.9511193863050682
# /home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/Test_Pos_sample_0154_tool_mask
# ImageID: 5. Dice co-efficient: 0.9696264841125272  Balanced Accuracy: 0.9866760235361995
#
# -----------------------Final Segmentation metrics are as follows:---------------------------
# DSC = 92.9240 (+/-6.3990)
# Sensitivity = 92.9334 (+/-5.5508)
# Specificity = 99.0675 (+/-3.7342)
# Accuracy = 98.54017646 (+/-3.1655)
# IoU = 87.3221 (+/-9.1164)
# Balanced Accuracy = 96.0004 (+/-3.1438)

# %% [markdown]
# ## Mid line mean angular displacement performance

# %%
CurrentDirectory=os.getcwd()
PredictionPath = '/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/'
Prediction = glob.glob(PredictionPath+"*.png")
Prediction.sort()
# print(len(Prediction))

OriginalMidlineGT = glob.glob('/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Test_Positive_MidLine/'+"*.png")
OriginalMidlineGT.sort()
# print(len(OriginalmaskGT))

OriginalImage = glob.glob('/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Test_Positive/'+"*.png")
OriginalImage.sort()
# print(len(OriginalImage))

midlinesavePath = '/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Results_Evaluation/Mid_line/'


i=0


AD_midline=[]
for Pred in Prediction:
    
    filename, file_extension = os.path.splitext(Pred) 
    
    if 'midline' in filename:
        #------------------------------------Read the Prediction from SIMO--------------------------------
        imgPred = cv2.imread(Pred,0)
        tempimgPred = imgPred.copy()
        #-----------------------------------Read Original Image with Midline GT---------------------------
        orimg = cv2.imread(OriginalImage[i],-1)
        orimg = cv2.resize(orimg,(256,192))
        
        trueLine = cv2.imread(OriginalMidlineGT[i],0)
        trueLine = cv2.resize(trueLine,(256,192))
        i=i+1
        #-------------------------------Truncate the intensity lower than Threshold----------------------
        Threshold = (imgPred.max())-100
        imgPred[imgPred<Threshold]=0
        
        temp = cv2.merge((tempimgPred, tempimgPred, tempimgPred))
        temp [:,:,0]=0
        temp [:,:,2]=0 

        
        savelinePath=midlinesavePath+'ImgID_'+filename[-11:]+'_Prediction_.png'
        cv2.imwrite(savelinePath,cv2.addWeighted(temp,0.99,orimg,0.8,0))
                
        
        #-----------------------------Classic straight-line Hough transform----------------------------
        h, theta, d = hough_line(imgPred)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d, min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0P = 0
        y0P = int(y0)
        x1P = imgPred.shape[1]
        y1P = int(y1)
        
        #-----------------------------Approximate Line-------------------------------------------------
        ApproximateLine=np.zeros_like(imgPred, dtype=np.uint8)
    
        cv2.line(ApproximateLine,(x0P,y0P),(x1P,y1P), 255, 1)
        
#         savelinePath=midlinesavePath+filename[-11:]+'_Approx_.png'
#         cv2.imwrite(savelinePath,ApproximateLine)  
        
        #---------------------------True Line approximation----------------------------------------------
        h, theta, d = hough_line(trueLine)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d,min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0G = 0
        y0G = int(y0)
        x1G= imgPred.shape[1]
        y1G= int(y1)
        
        trueLine=np.zeros_like(trueLine, dtype=np.uint8)
    
        cv2.line(trueLine,(x0G,y0G),(x1G,y1G), 255, 1)   
        
        
        #-----------------------Overlay with original Image------------------------------------------       
        temp = cv2.merge((ApproximateLine, ApproximateLine, ApproximateLine))
        temp [:,:,0]=0
        temp [:,:,2]=0 
        
        temp2 = cv2.merge((trueLine, trueLine, trueLine))
        temp2 [:,:,0]=0 

        
        dummy = cv2.addWeighted(temp,0.99,orimg,0.8,0)
        
        dummy = cv2.addWeighted(temp2,0.99,dummy,0.8,0)
        
        
        #----------------------mean Angular Displacement Error Measurements--------------------------

        AngularDisplacement=Angular_Displacement(height = 192,
                                                width = 256,
                                                L1x1 = x0P,
                                                L1y1 = y0P,
                                                L1x2 = x1P,
                                                L1y2 = y1P,
                                                L2x1 = x0G,
                                                L2y1 = y0G,
                                                L2x2 = x1G,
                                                L2y2 = y1G)
        
        print('ImageID: '+ filename[-11:-8]+'.  AD in radian: '+ str(AngularDisplacement)
              + '  AD in degrees: ' + str(degrees(AngularDisplacement)))
        
        
        #------------------------ApproximateLine with True Line---------------------------------------
        
        TruePlusApproximation = ApproximateLine+trueLine
        
        font                   = cv2.FONT_HERSHEY_SIMPLEX
        bottomLeftCornerOfText = (80,185)
        fontScale              = 1
        fontColor              = (255,255,255)
        lineType               = 2

        cv2.putText(dummy,str(round (degrees(AngularDisplacement),2)), 
            bottomLeftCornerOfText, 
            font, 
            fontScale,
            fontColor,
            lineType)

#         savelinePath=midlinesavePath+filename[-11:]+'_ApproxPlusTrue_.png'
#         cv2.imwrite(savelinePath,TruePlusApproximation) 
        
        savelinePath=midlinesavePath+'ImgID_'+filename[-11:]+'_Overlay_with_Approx_true_.png'
        cv2.imwrite(savelinePath,dummy)  

        AD_midline.append(AngularDisplacement)
  
print()
print('-----------------------Final mean Angular Displacement (mAD)---------------------------')
print()
print('mAD in radians: '+ str(np.mean(AD_midline)) + '  mAD in degrees: ' + str(degrees(np.mean(AD_midline))))
print('std. AD in radians: '+ str(math.sqrt(np.mean((np.array(AD_midline)-np.mean(AD_midline))**2))) 
      + '  median AD in radians: ' + str(np.median(AD_midline)))
# Out:
# ImageID: 001.  AD in radian: 0.0193529796777810  AD in degrees: 1.1088440565393032
# ImageID: 002.  AD in radian: 0.106437890272833  AD in degrees: 6.098441892909874
# ImageID: 003.  AD in radian: 0.0572832193014515  AD in degrees: 3.282086702895505
# ImageID: 004.  AD in radian: 0.298601844362136  AD in degrees: 17.108625436772655
# ImageID: 005.  AD in radian: 0.313497999634434  AD in degrees: 17.962112264846887
# ImageID: 006.  AD in radian: 0.0202261334223564  AD in degrees: 1.1588720809695152
# ImageID: 007.  AD in radian: 0.0367613415983628  AD in degrees: 2.1062697228248966
# ImageID: 008.  AD in radian: 0.0179297698816290  AD in degrees: 1.0273001418581185
# ImageID: 009.  AD in radian: 0.124830050311230  AD in degrees: 7.152235039239212
# ImageID: 010.  AD in radian: 0.0855515063749158  AD in degrees: 4.901740246269234
# ImageID: 011.  AD in radian: 0.0181301593709445  AD in degrees: 1.0387816138546797
# ImageID: 012.  AD in radian: 0.0196276873981894  AD in degrees: 1.124583649518362
# ImageID: 013.  AD in radian: 0.0166924425897871  AD in degrees: 0.9564065101592267
# ImageID: 014.  AD in radian: 0.334581840611736  AD in degrees: 19.170127368771276
# ImageID: 015.  AD in radian: 0.0537273348993016  AD in degrees: 3.078349534215916
# ImageID: 016.  AD in radian: 0.0249748716066398  AD in degrees: 1.430954736941575
# ImageID: 017.  AD in radian: 0.0279063942453704  AD in degrees: 1.5989186116878895
# ImageID: 018.  AD in radian: 0.0457268223697126  AD in degrees: 2.6199539323289356
# ImageID: 019.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 020.  AD in radian: 0.0195287670414137  AD in degrees: 1.1189159305671905
# ImageID: 021.  AD in radian: 0.0877619713896076  AD in degrees: 5.028390562372398
# ImageID: 022.  AD in radian: 0.194242151242704  AD in degrees: 11.129255469748783
# ImageID: 023.  AD in radian: 0.454487234640339  AD in degrees: 26.04020038746335
# ImageID: 024.  AD in radian: 0.174976692513969  AD in degrees: 10.02542599420877
# ImageID: 025.  AD in radian: 0.0513819335038729  AD in degrees: 2.9439679329937603
# ImageID: 026.  AD in radian: 0.0535022811059459  AD in degrees: 3.0654549016932244
# ImageID: 027.  AD in radian: 0.0121740073357010  AD in degrees: 0.6975192400969726
# ImageID: 028.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 029.  AD in radian: 0.0192875732444782  AD in degrees: 1.1050965439580471
# ImageID: 030.  AD in radian: 0.0153061473303406  AD in degrees: 0.8769776426339512
# ImageID: 031.  AD in radian: 0.0343009786203098  AD in degrees: 1.9653013081122217
# ImageID: 032.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 033.  AD in radian: 0.0456799746762977  AD in degrees: 2.617269757216337
# ImageID: 034.  AD in radian: 0.0352631196356515  AD in degrees: 2.020427927587733
# ImageID: 035.  AD in radian: 0.00931232770067025  AD in degrees: 0.5335570746911714
# ImageID: 036.  AD in radian: 0.0350137912752468  AD in degrees: 2.0061424648236263
# ImageID: 037.  AD in radian: 0.0685464598581797  AD in degrees: 3.9274228504366104
# ImageID: 038.  AD in radian: 0.155922844694119  AD in degrees: 8.933720930646793
# ImageID: 039.  AD in radian: 0.0162516528062019  AD in degrees: 0.9311511159073118
# ImageID: 040.  AD in radian: 0.0543435394039432  AD in degrees: 3.113655451648833
# ImageID: 041.  AD in radian: 0.0208077487108326  AD in degrees: 1.1921961822994878
# ImageID: 042.  AD in radian: 0.0163697550017795  AD in degrees: 0.9379178732651352
# ImageID: 043.  AD in radian: 0.240599291768581  AD in degrees: 13.785323972176379
# ImageID: 044.  AD in radian: 0.334438470663755  AD in degrees: 19.16191287584297
# ImageID: 045.  AD in radian: 0.580430782319448  AD in degrees: 33.25623412638097
# ImageID: 046.  AD in radian: 0.383454901269289  AD in degrees: 21.97034747633592
# ImageID: 047.  AD in radian: 0.0248534185311181  AD in degrees: 1.4239959883052953
# ImageID: 048.  AD in radian: 0.0370249324248835  AD in degrees: 2.1213723647028973
# ImageID: 049.  AD in radian: 0.0153061473303406  AD in degrees: 0.8769776426339495
# ImageID: 050.  AD in radian: 0.0158572649498398  AD in degrees: 0.908554356246548
# ImageID: 051.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 052.  AD in radian: 0.0657705029914620  AD in degrees: 3.7683722378633266
# ImageID: 053.  AD in radian: 0.0248534185311181  AD in degrees: 1.4239959883052953
# ImageID: 054.  AD in radian: 0.0150968500221537  AD in degrees: 0.8649857902113888
# ImageID: 055.  AD in radian: 0.0143592531012531  AD in degrees: 0.8227245996619391
# ImageID: 056.  AD in radian: 0.0520943508688895  AD in degrees: 2.984786441261043
# ImageID: 057.  AD in radian: 0.0525816228841573  AD in degrees: 3.0127050712107217
# ImageID: 058.  AD in radian: 0.0543435394039433  AD in degrees: 3.1136554516488357
# ImageID: 059.  AD in radian: 0.0203321031529131  AD in degrees: 1.1649436992865552
# ImageID: 060.  AD in radian: 0.00569817729871820  AD in degrees: 0.3264815101338091
# ImageID: 061.  AD in radian: 0.125390284058045  AD in degrees: 7.184334068472516
# ImageID: 062.  AD in radian: 0.0282592415462389  AD in degrees: 1.619135272840238
# ImageID: 063.  AD in radian: 0.0133110303566845  AD in degrees: 0.762665860408538
# ImageID: 064.  AD in radian: 0.0116738058194953  AD in degrees: 0.6688598043123416
# ImageID: 065.  AD in radian: 0.0387449859179952  AD in degrees: 2.219924170394935
# ImageID: 066.  AD in radian: 0.0782768278168798  AD in degrees: 4.484931867579456
# ImageID: 067.  AD in radian: 0.0514168282753519  AD in degrees: 2.9459672561265817
# ImageID: 068.  AD in radian: 0.0525816228841574  AD in degrees: 3.012705071210725
# ImageID: 069.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 070.  AD in radian: 0.0150702925999308  AD in degrees: 0.8634641620032694
# ImageID: 071.  AD in radian: 0.0373325128201134  AD in degrees: 2.138995423210537
# ImageID: 072.  AD in radian: 0.0159520979675282  AD in degrees: 0.9139878879185855
# ImageID: 073.  AD in radian: 0.0137278159967665  AD in degrees: 0.7865459185468963
# ImageID: 074.  AD in radian: 0.0196718609989011  AD in degrees: 1.127114610405042
# ImageID: 075.  AD in radian: 0.139740510768197  AD in degrees: 8.006541494020098
# ImageID: 076.  AD in radian: 0.123204304167538  AD in degrees: 7.059086646646008
# ImageID: 077.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 078.  AD in radian: 0.0351035770856850  AD in degrees: 2.0112868128218984
# ImageID: 079.  AD in radian: 0.524211531239598  AD in degrees: 30.035108312119245
# ImageID: 080.  AD in radian: 0.00717173713552642  AD in degrees: 0.41091026964290633
# ImageID: 081.  AD in radian: 0.387357165566237  AD in degrees: 22.193930751095664
# ImageID: 082.  AD in radian: 0.188618326216451  AD in degrees: 10.807034031024402
# ImageID: 083.  AD in radian: 0.0222450187848046  AD in degrees: 1.2745456915585387
# ImageID: 084.  AD in radian: 0.0338341672324475  AD in degrees: 1.938554985759066
# ImageID: 085.  AD in radian: 0.0192018645979391  AD in degrees: 1.1001858002435798
# ImageID: 086.  AD in radian: 0.0177335506783396  AD in degrees: 1.0160576096502187
# ImageID: 087.  AD in radian: 0.0340767039423436  AD in degrees: 1.9524513156131031
# ImageID: 088.  AD in radian: 0.0525319971437984  AD in degrees: 3.009861725732942
# ImageID: 089.  AD in radian: 0.0190415388123630  AD in degrees: 1.0909998093829523
# ImageID: 090.  AD in radian: 0.00613510957781477  AD in degrees: 0.35151588565907455
# ImageID: 091.  AD in radian: 0.0313013050917634  AD in degrees: 1.7934326750093978
# ImageID: 092.  AD in radian: 0.123204304167538  AD in degrees: 7.059086646646007
# ImageID: 093.  AD in radian: 0.0181064452377120  AD in degrees: 1.0374228941056456
# ImageID: 094.  AD in radian: 0.0362197067157702  AD in degrees: 2.0752363300152754
# ImageID: 095.  AD in radian: 0.0332540753752895  AD in degrees: 1.9053181706140068
# ImageID: 096.  AD in radian: 0.0171912629828510  AD in degrees: 0.9849868134168452
# ImageID: 097.  AD in radian: 0.0881719524879209  AD in degrees: 5.051880748985887
# ImageID: 098.  AD in radian: 0.0315073955836758  AD in degrees: 1.8052407903937522
# ImageID: 099.  AD in radian: 0.105030923792466  AD in degrees: 6.017828651668461
# ImageID: 100.  AD in radian: 0.0168978423199114  AD in degrees: 0.9681750478084734
# ImageID: 101.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 102.  AD in radian: 0.0198357684980444  AD in degrees: 1.1365058183364973
# ImageID: 103.  AD in radian: 0.0254248818765271  AD in degrees: 1.4567384261436618
# ImageID: 104.  AD in radian: 0.105446244297175  AD in degrees: 6.041624763733576
# ImageID: 105.  AD in radian: 0.0520861735579673  AD in degrees: 2.984317915857435
# ImageID: 106.  AD in radian: 0.305463723886031  AD in degrees: 17.501782173019084
# ImageID: 107.  AD in radian: 0.228815201484699  AD in degrees: 13.110145333508813
# ImageID: 108.  AD in radian: 0.0528735604390387  AD in degrees: 3.029431860986791
# ImageID: 109.  AD in radian: 0.0857178068956618  AD in degrees: 4.911268564238807
# ImageID: 110.  AD in radian: 0.847556029825817  AD in degrees: 48.561383409883454
# ImageID: 111.  AD in radian: 0.0878251937417089  AD in degrees: 5.032012936318691
# ImageID: 112.  AD in radian: 0.350706148009596  AD in degrees: 20.09398213024024
# ImageID: 113.  AD in radian: 1.17447394216789  AD in degrees: 67.2924000343122
# ImageID: 114.  AD in radian: 0.0134469445953261  AD in degrees: 0.7704531726584404
# ImageID: 115.  AD in radian: 0.123033463097079  AD in degrees: 7.049298174341198
# ImageID: 116.  AD in radian: 0.0179680225715584  AD in degrees: 1.0294918595460947
# ImageID: 117.  AD in radian: 1.07012108658772  AD in degrees: 61.31342182943023
# ImageID: 118.  AD in radian: 0.0177848948756068  AD in degrees: 1.0189994154561137
# ImageID: 119.  AD in radian: 0.0360473195755250  AD in degrees: 2.0653592744368994
# ImageID: 120.  AD in radian: 0.0551807110843531  AD in degrees: 3.1616218556641926
# ImageID: 121.  AD in radian: 0.0533580825939217  AD in degrees: 3.057192935542171
# ImageID: 122.  AD in radian: 0.0158572649498398  AD in degrees: 0.908554356246551
# ImageID: 123.  AD in radian: 0.0354882257074547  AD in degrees: 2.0333255554448257
# ImageID: 124.  AD in radian: 0.0365379582308199  AD in degrees: 2.0934707986512655
# ImageID: 125.  AD in radian: 0.0533448163838653  AD in degrees: 3.056432837695807
# ImageID: 126.  AD in radian: 0.0359207682704747  AD in degrees: 2.0581084187656407
# ImageID: 127.  AD in radian: 0.0179676213543716  AD in degrees: 1.0294688714946258
# ImageID: 128.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 129.  AD in radian: 0.0138802276211679  AD in degrees: 0.7952784613738334
# ImageID: 130.  AD in radian: 0.0193529796777810  AD in degrees: 1.1088440565393052
# ImageID: 131.  AD in radian: 0.155863311374948  AD in degrees: 8.93030992271793
# ImageID: 132.  AD in radian: 0.229147367533926  AD in degrees: 13.129177046227067
# ImageID: 133.  AD in radian: 0.120813865876362  AD in degrees: 6.922124621375146
# ImageID: 134.  AD in radian: 0.156742404908565  AD in degrees: 8.9806782719914
# ImageID: 135.  AD in radian: 0.0328828094349519  AD in degrees: 1.8840461991557067
# ImageID: 136.  AD in radian: 0.0173237430518563  AD in degrees: 0.9925773622404518
# ImageID: 137.  AD in radian: 0.00707902931857998  AD in degrees: 0.40559850300400396
# ImageID: 138.  AD in radian: 0.135806991358439  AD in degrees: 7.781167433208222
# ImageID: 139.  AD in radian: 0.456621744437474  AD in degrees: 26.162498790168527
# ImageID: 140.  AD in radian: 0.738506156385474  AD in degrees: 42.31328590531602
# ImageID: 141.  AD in radian: 0.0353443909537006  AD in degrees: 2.025084431107408
# ImageID: 142.  AD in radian: 0.0566017163696167  AD in degrees: 3.243039461175582
# ImageID: 143.  AD in radian: 0.00703124999663238  AD in degrees: 0.4028609495084099
# ImageID: 144.  AD in radian: 0.00862159067031780  AD in degrees: 0.4939807580985763
# ImageID: 145.  AD in radian: 0.0230136735331947  AD in degrees: 1.3185863645439844
# ImageID: 146.  AD in radian: 0.0519579675617127  AD in degrees: 2.9769722533637735
# ImageID: 147.  AD in radian: 0.0162516528062019  AD in degrees: 0.9311511159073084
# ImageID: 148.  AD in radian: 0.0176427685872026  AD in degrees: 1.0108561789726924
# ImageID: 149.  AD in radian: 0.228815201484699  AD in degrees: 13.110145333508813
# ImageID: 150.  AD in radian: 0.0183536251654443  AD in degrees: 1.0515852607450564
# ImageID: 151.  AD in radian: 0.144236256724231  AD in degrees: 8.26412876306389
# ImageID: 152.  AD in radian: 0.0187517877969589  AD in degrees: 1.0743982990906664
# ImageID: 153.  AD in radian: 0.0220564526269400  AD in degrees: 1.263741646553898
# ImageID: 154.  AD in radian: 0.322405447441247  AD in degrees: 18.472471430410355
#
# -----------------------Final mean Angular Displacement (mAD)---------------------------
#
# mAD in radians: 0.102073273105130  mAD in degrees: 5.848367750010176
# std. AD in radians: 0.1795914638885426  median AD in radians: 0.0353037552946760

# %% [markdown]
# ## Edge lines mean angular displacement performance

# %%
testGene = '/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/'
Prediction = glob.glob(testGene+"*.png")
Prediction.sort()
#print(len(Prediction))

OriginalupGT = glob.glob('/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Test_Positive_EdgeLine_1/'+"*.png")
OriginalupGT.sort()
#print(len(OriginalupGT))


OriginallowGT = glob.glob('/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Test_Positive_EdgeLine_2/'+"*.png")
OriginallowGT.sort()
#print(len(OriginallowGT))


OriginalImage = glob.glob('/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Test_Positive/'+"*.png")
OriginalImage.sort()
#print(len(OriginalImage))

midlinesavePath = '/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Results_Evaluation/EdgeLines/'


i=0

AngularDisplacement_Line_1 = []
AngularDisplacement_Line_2 = []
bothError=[]

for Pred in Prediction:
    
    filename, file_extension = os.path.splitext(Pred) 
    
    if 'edgeLine' in filename:
        #--------------------------Read the Prediction from SIMO----------------------------------------
        imgPred = cv2.imread(Pred,0)
        temp = imgPred.copy()
        temp2 = imgPred.copy()
        
        #-------------------------Read Original Image with Midline GT-----------------------------------
        orimg = cv2.imread(OriginalImage[i],-1)
        orimg = cv2.resize(orimg,(256,192))
        
        up = cv2.imread(OriginalupGT[i],0)
        up = cv2.resize(up,(256,192))
        
        up[up<100]=0
        up[up>100]=255
        
        low = cv2.imread(OriginallowGT[i],0)
        low = cv2.resize(low,(256,192))
        low[low<100]=0
        low[low>100]=255
        
        trueline=up+low
        
        i=i+1

        #-----------------------Truncate the intensity lower than Threshold--------------------------
        imgPredtemp=imgPred.copy()
        
        Threshold = (imgPred.max())-100
        imgPred[imgPred<Threshold]=0
        imgPredtemp[imgPredtemp<Threshold-30]=0
        
        
        
#         savelinePath=midlinesavePath+filename[-13:]+'_Pred_.png'
#         cv2.imwrite(savelinePath,imgPred)
        
#         savelinePath=midlinesavePath+filename[-13:]+'_true_.png'
#         cv2.imwrite(savelinePath,trueline)
        
#         savelinePath=midlinesavePath+filename[-13:]+'_truePLUSPred_.png'
#         cv2.imwrite(savelinePath,trueline+imgPred)
                
        
        #-----------------------Classic straight-line Hough transform-------------------------------
        h, theta, d = hough_line(imgPred)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d,min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0P1 = 0
        y0P1 = int(y0)
        x1P1 = imgPred.shape[1]
        y1P1 = int(y1)
        
        #-------------------------Approximate Line_1------------------------------------------------
        ApproximateLine1=np.zeros_like(imgPred, dtype=np.uint8)
    
        cv2.line(ApproximateLine1,(x0P1,y0P1),(x1P1,y1P1), 255, 1)       
        
        #------------------------Classic straight-line Hough transform------------------------------
        temp=np.zeros_like(imgPred, dtype=np.uint8)
        temp=cv2.line(temp,(x0P1,y0P1),(x1P1,y1P1), 255, 15)
        
        temp = 255-temp
        
        imgPred=imgPred & temp
        
        h, theta, d = hough_line(imgPred)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d,min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0P2 = 0
        y0P2 = int(y0)
        x1P2 = imgPred.shape[1]
        y1P2 = int(y1)
        
        #-------------------------Approximate Line_2------------------------------------------------
        ApproximateLine2=np.zeros_like(imgPred, dtype=np.uint8)
    
        cv2.line(ApproximateLine2,(x0P2,y0P2),(x1P2,y1P2), 255, 1)
        
        ApproximateLine = ApproximateLine2 + ApproximateLine1
        

        cv2.imwrite(midlinesavePath+filename[-13:]+'_Line_1_.png',ApproximateLine1) 
        cv2.imwrite(midlinesavePath+filename[-13:]+'_Line_2_.png',ApproximateLine2) 
        
        
        #-----------------------True Line-1 approximation------------------------------------------
        h, theta, d = hough_line(trueline)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d,min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0G1 = 0
        y0G1 = int(y0)
        x1G1= imgPred.shape[1]
        y1G1= int(y1)
        
        up=np.zeros_like(trueline, dtype=np.uint8)
    
        cv2.line(up,(x0G1,y0G1),(x1G1,y1G1), 255, 1)  
        
        temp=np.zeros_like(trueline, dtype=np.uint8)
    
        cv2.line(temp,(x0G1,y0G1),(x1G1,y1G1), 255, 15) 
        temp = 255-temp
        
        trueline= trueline & temp
        
        labelImage=label(trueline)
        regions=regionprops(labelImage)
        Area=[]
        for region in range(len(regions)):
            maxThreshold=regions[region].area,
            Area.append(maxThreshold)
        X= sorted( [(x,i) for (i,x) in enumerate(Area)], reverse=True )[:2]

        index=np.array(X)
        V=index.T[1].tolist()
        trueline[labelImage!=(V[0]+1)]=0
        
        h, theta, d = hough_line(trueline)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d,min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0G2 = 0
        y0G2 = int(y0)
        x1G2= imgPred.shape[1]
        y1G2= int(y1)
        
        low=np.zeros_like(trueline, dtype=np.uint8)
    
        cv2.line(low,(x0G2,y0G2),(x1G2,y1G2), 255, 1)   
        
        trueline = up+low

#         savelinePath=midlinesavePath+filename[-13:]+'_ApproxPLUStrue_.png'
#         cv2.imwrite(savelinePath,ApproximateLine+trueline) 
        
        #-------------------Overlay with original Image-------------------------------       
        temp = cv2.merge((ApproximateLine, ApproximateLine, ApproximateLine))
        temp [:,:,0]=0
        temp [:,:,2]=0  
        
        temp1 = cv2.merge((trueline, trueline, trueline))
        temp1 [:,:,0]=0

        
        dummy1 = cv2.addWeighted(temp,0.99,orimg,0.8,0)
        dummy2 = cv2.addWeighted(temp1,0.99,dummy1,0.8,0)
        
#         savelinePath=midlinesavePath+filename[-13:]+'_overlay_.png'
#         cv2.imwrite(savelinePath,dummy2) 
        
        
        AngularDisplacement_approx1_up=Angular_Displacement(height = 192,
                                                            width = 256,
                                                            L1x1 = x0P1,
                                                            L1y1 = y0P1,
                                                            L1x2 = x1P1,
                                                            L1y2 = y1P1,
                                                            L2x1 = x0G1,
                                                            L2y1 = y0G1,
                                                            L2x2 = x1G1,
                                                            L2y2 = y1G1)
        
        AngularDisplacement_approx1_low=Angular_Displacement(height = 192,
                                                            width = 256,
                                                            L1x1 = x0P1,
                                                            L1y1 = y0P1,
                                                            L1x2 = x1P1,
                                                            L1y2 = y1P1,
                                                            L2x1 = x0G2,
                                                            L2y1 = y0G2,
                                                            L2x2 = x1G2,
                                                            L2y2 = y1G2)
        
        AngularDisplacement_approx2_up=Angular_Displacement(height = 192,
                                                            width = 256,
                                                            L1x1 = x0P2,
                                                            L1y1 = y0P2,
                                                            L1x2 = x1P2,
                                                            L1y2 = y1P2,
                                                            L2x1 = x0G1,
                                                            L2y1 = y0G1,
                                                            L2x2 = x1G1,
                                                            L2y2 = y1G1)
        
        AngularDisplacement_approx2_low=Angular_Displacement(height = 192,
                                                            width = 256,
                                                            L1x1 = x0P2,
                                                            L1y1 = y0P2,
                                                            L1x2 = x1P2,
                                                            L1y2 = y1P2,
                                                            L2x1 = x0G2,
                                                            L2y1 = y0G2,
                                                            L2x2 = x1G2,
                                                            L2y2 = y1G2)
        
        if AngularDisplacement_approx1_up>AngularDisplacement_approx1_low:
            line_1_Error = AngularDisplacement_approx1_low
        else:
            line_1_Error = AngularDisplacement_approx1_up
    
        AngularDisplacement_Line_1.append(line_1_Error)
        
        if AngularDisplacement_approx2_up>AngularDisplacement_approx2_low:
            line_2_Error = AngularDisplacement_approx2_low
        else:
            line_2_Error = AngularDisplacement_approx2_up
    
        AngularDisplacement_Line_2.append(line_2_Error)

        Error= (line_1_Error+line_2_Error)/2
        
        bothError.append(Error)
        
        font                   = cv2.FONT_HERSHEY_SIMPLEX
        bottomLeftCornerOfText = (80,185)
        fontScale              = 1
        fontColor              = (255,255,255)
        lineType               = 2

        cv2.putText(dummy2,str(round(degrees(Error),2)), 
            bottomLeftCornerOfText, 
            font, 
            fontScale,
            fontColor,
            lineType)
        savelinePath=midlinesavePath+'ImgID_'+filename[-12:]+'_Pred_True-EdgeLine.png'
        cv2.imwrite(savelinePath,dummy2) 
        
        print('Angular Displacement (AD) in radian: '+ str(Error)
              + '  Angular Displacement (AD) in degrees: ' + str(degrees(Error)))

        
  
print()
print('-----------------------Final mean Angular Displacement (mAD)---------------------------')
print()
print('mAD in radians: '+ str(np.mean(bothError)) + '  mAD in degrees: ' + str(degrees(np.mean(bothError))))
print('std. AD in radians: '+ str(math.sqrt(np.mean((np.array(bothError)-np.mean(bothError))**2))) 
      + '  median AD in radians: ' + str(np.median(bothError)))
# Out:
# <ipython-input-13-07d3d34f27d0>:150: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   index=np.array(X)
# Angular Displacement (AD) in radian: 0.0111387166358405  Angular Displacement (AD) in degrees: 0.6382014524258175
# Angular Displacement (AD) in radian: 0.0207124699565603  Angular Displacement (AD) in degrees: 1.1867371118024208
# Angular Displacement (AD) in radian: 0.0169980228730903  Angular Displacement (AD) in degrees: 0.9739149706949138
# Angular Displacement (AD) in radian: 0.0280428152606077  Angular Displacement (AD) in degrees: 1.6067349600978782
# Angular Displacement (AD) in radian: 0.0325537540977238  Angular Displacement (AD) in degrees: 1.8651927171062834
# Angular Displacement (AD) in radian: 0.0228598872339843  Angular Displacement (AD) in degrees: 1.309775058652288
# Angular Displacement (AD) in radian: 0.0183071310004733  Angular Displacement (AD) in degrees: 1.04892134132023
# Angular Displacement (AD) in radian: 0.0260922089699861  Angular Displacement (AD) in degrees: 1.4949734521535938
# Angular Displacement (AD) in radian: 0.00974565121828136  Angular Displacement (AD) in degrees: 0.5583846834140511
# Angular Displacement (AD) in radian: 0.0175708884013984  Angular Displacement (AD) in degrees: 1.0067377476954988
# Angular Displacement (AD) in radian: 0.0530802654604256  Angular Displacement (AD) in degrees: 3.0412751863164265
# Angular Displacement (AD) in radian: 0.0158962924537177  Angular Displacement (AD) in degrees: 0.910790467503685
# Angular Displacement (AD) in radian: 0.0314701861938741  Angular Displacement (AD) in degrees: 1.8031088493998566
# Angular Displacement (AD) in radian: 0.0917530350285438  Angular Displacement (AD) in degrees: 5.257061664651564
# Angular Displacement (AD) in radian: 0.0257853158730628  Angular Displacement (AD) in degrees: 1.477389772938185
# Angular Displacement (AD) in radian: 0.00884262323661155  Angular Displacement (AD) in degrees: 0.5066449912821537
# Angular Displacement (AD) in radian: 0.0134744528171365  Angular Displacement (AD) in degrees: 0.7720292776700853
# Angular Displacement (AD) in radian: 0.0247881452291894  Angular Displacement (AD) in degrees: 1.4202561035899
# Angular Displacement (AD) in radian: 0.0145558127814221  Angular Displacement (AD) in degrees: 0.8339866397580662
# Angular Displacement (AD) in radian: 0.0894324287985327  Angular Displacement (AD) in degrees: 5.124100721760162
# Angular Displacement (AD) in radian: 0.0169204700039802  Angular Displacement (AD) in degrees: 0.9694715186057709
# Angular Displacement (AD) in radian: 0.0297152411763042  Angular Displacement (AD) in degrees: 1.7025579066155883
# Angular Displacement (AD) in radian: 0.0195942086022715  Angular Displacement (AD) in degrees: 1.122665455809091
# Angular Displacement (AD) in radian: 0.00953436316860898  Angular Displacement (AD) in degrees: 0.546278769906273
# Angular Displacement (AD) in radian: 0.0163340821032375  Angular Displacement (AD) in degrees: 0.9358739667356782
# Angular Displacement (AD) in radian: 0.0176381252349353  Angular Displacement (AD) in degrees: 1.0105901344849841
# Angular Displacement (AD) in radian: 0.00309383912571325  Angular Displacement (AD) in degrees: 0.17726392439581395
# Angular Displacement (AD) in radian: 0.0202891589168021  Angular Displacement (AD) in degrees: 1.1624831758029797
# Angular Displacement (AD) in radian: 0.0256421112722931  Angular Displacement (AD) in degrees: 1.4691847537072285
# Angular Displacement (AD) in radian: 0.0256637084247112  Angular Displacement (AD) in degrees: 1.4704221793902872
# Angular Displacement (AD) in radian: 0.0273685414926005  Angular Displacement (AD) in degrees: 1.5681019189546852
# Angular Displacement (AD) in radian: 0.00560605839142476  Angular Displacement (AD) in degrees: 0.32120348553253825
# Angular Displacement (AD) in radian: 0.0217131260251819  Angular Displacement (AD) in degrees: 1.2440704812785914
# Angular Displacement (AD) in radian: 0.0439646400795589  Angular Displacement (AD) in degrees: 2.5189883243704294
# Angular Displacement (AD) in radian: 0.0176376944820051  Angular Displacement (AD) in degrees: 1.0105654541600715
# Angular Displacement (AD) in radian: 0.0178634588082388  Angular Displacement (AD) in degrees: 1.0235007972178811
# Angular Displacement (AD) in radian: 0.00310750681238303  Angular Displacement (AD) in degrees: 0.17804702515769963
# Angular Displacement (AD) in radian: 0.0454908329582774  Angular Displacement (AD) in degrees: 2.6064327350439216
# Angular Displacement (AD) in radian: 0.00795762986911198  Angular Displacement (AD) in degrees: 0.4559386064273583
# Angular Displacement (AD) in radian: 0.0706039490749124  Angular Displacement (AD) in degrees: 4.045308298949076
# Angular Displacement (AD) in radian: 0.0326257517137434  Angular Displacement (AD) in degrees: 1.8693178766392111
# Angular Displacement (AD) in radian: 0.0152288370827814  Angular Displacement (AD) in degrees: 0.8725480917356934
# Angular Displacement (AD) in radian: 0.0884877808505738  Angular Displacement (AD) in degrees: 5.0699763812164225
# Angular Displacement (AD) in radian: 0.0528265654438692  Angular Displacement (AD) in degrees: 3.026739246105343
# Angular Displacement (AD) in radian: 0.0659427099140876  Angular Displacement (AD) in degrees: 3.778238967732711
# Angular Displacement (AD) in radian: 0.0536995009112222  Angular Displacement (AD) in degrees: 3.076754764171951
# Angular Displacement (AD) in radian: 0.0168480706187849  Angular Displacement (AD) in degrees: 0.9653233393947401
# Angular Displacement (AD) in radian: 0.00905877484694802  Angular Displacement (AD) in degrees: 0.5190295662893897
# Angular Displacement (AD) in radian: 0.0264452391133170  Angular Displacement (AD) in degrees: 1.5152005894073501
# Angular Displacement (AD) in radian: 0.0245384679129951  Angular Displacement (AD) in degrees: 1.4059506471318153
# Angular Displacement (AD) in radian: 0.0117851191861182  Angular Displacement (AD) in degrees: 0.6752375904232231
# Angular Displacement (AD) in radian: 0.0340536350275667  Angular Displacement (AD) in degrees: 1.9511295641584405
# Angular Displacement (AD) in radian: 0.00328798832319427  Angular Displacement (AD) in degrees: 0.1883878540073284
# Angular Displacement (AD) in radian: 0.0169804702239797  Angular Displacement (AD) in degrees: 0.9729092779816033
# Angular Displacement (AD) in radian: 0.0129858993462217  Angular Displacement (AD) in degrees: 0.7440372257201999
# Angular Displacement (AD) in radian: 0.0297770812811648  Angular Displacement (AD) in degrees: 1.7061010836287502
# Angular Displacement (AD) in radian: 0.0218072436718952  Angular Displacement (AD) in degrees: 1.2494630252129693
# Angular Displacement (AD) in radian: 0.0249582342538057  Angular Displacement (AD) in degrees: 1.4300014868419118
# Angular Displacement (AD) in radian: 0.0193677772055888  Angular Displacement (AD) in degrees: 1.1096918924299175
# Angular Displacement (AD) in radian: 0.00884262323661156  Angular Displacement (AD) in degrees: 0.5066449912821543
# Angular Displacement (AD) in radian: 0.0426565156401241  Angular Displacement (AD) in degrees: 2.4440383149128984
# Angular Displacement (AD) in radian: 0.0221521198063365  Angular Displacement (AD) in degrees: 1.2692229721712376
# Angular Displacement (AD) in radian: 0.0249364089162537  Angular Displacement (AD) in degrees: 1.4287509871137345
# Angular Displacement (AD) in radian: 0.0170633644322985  Angular Displacement (AD) in degrees: 0.9776587662643463
# Angular Displacement (AD) in radian: 0.0368416565225452  Angular Displacement (AD) in degrees: 2.1108714290124597
# Angular Displacement (AD) in radian: 0.0618140276265006  Angular Displacement (AD) in degrees: 3.541682897703558
# Angular Displacement (AD) in radian: 0.0204873609688376  Angular Displacement (AD) in degrees: 1.1738393168754477
# Angular Displacement (AD) in radian: 0.00923540204160748  Angular Displacement (AD) in degrees: 0.5291495590906126
# Angular Displacement (AD) in radian: 0.0262549702107760  Angular Displacement (AD) in degrees: 1.5042989843191659
# Angular Displacement (AD) in radian: 0.0189338103587929  Angular Displacement (AD) in degrees: 1.0848274236599118
# Angular Displacement (AD) in radian: 0.00937750411772141  Angular Displacement (AD) in degrees: 0.5372914083119876
# Angular Displacement (AD) in radian: 0.0616923641005566  Angular Displacement (AD) in degrees: 3.5347120911462873
# Angular Displacement (AD) in radian: 0.0424521965135672  Angular Displacement (AD) in degrees: 2.432331691287387
# Angular Displacement (AD) in radian: 0.0242375957541919  Angular Displacement (AD) in degrees: 1.388711942259398
# Angular Displacement (AD) in radian: 0.00877636965730678  Angular Displacement (AD) in degrees: 0.5028489408103554
# Angular Displacement (AD) in radian: 0.0111160374250142  Angular Displacement (AD) in degrees: 0.6369020293627822
# Angular Displacement (AD) in radian: 0.0188351203965697  Angular Displacement (AD) in degrees: 1.0791729053442158
# Angular Displacement (AD) in radian: 0.0351892857112322  Angular Displacement (AD) in degrees: 2.016197555333618
# Angular Displacement (AD) in radian: 0.0180466208469011  Angular Displacement (AD) in degrees: 1.033995209000239
# Angular Displacement (AD) in radian: 0.0197964222316717  Angular Displacement (AD) in degrees: 1.1342514433337456
# Angular Displacement (AD) in radian: 0.0268232792917162  Angular Displacement (AD) in degrees: 1.5368606961159976
# Angular Displacement (AD) in radian: 0.580595359952476  Angular Displacement (AD) in degrees: 33.26566373015571
# Angular Displacement (AD) in radian: 0.0282625672127233  Angular Displacement (AD) in degrees: 1.6193258194938662
# Angular Displacement (AD) in radian: 0.0171468813219453  Angular Displacement (AD) in degrees: 0.9824439315591702
# Angular Displacement (AD) in radian: 0.0298886881313687  Angular Displacement (AD) in degrees: 1.712495685110183
# Angular Displacement (AD) in radian: 0.0314387213799233  Angular Displacement (AD) in degrees: 1.801306048357312
# Angular Displacement (AD) in radian: 0.0396191250714360  Angular Displacement (AD) in degrees: 2.2700086545942275
# Angular Displacement (AD) in radian: 0.0278097360395751  Angular Displacement (AD) in degrees: 1.593380504440515
# Angular Displacement (AD) in radian: 0.0331178102596472  Angular Displacement (AD) in degrees: 1.8975107545928394
# Angular Displacement (AD) in radian: 0.00949131033852250  Angular Displacement (AD) in degrees: 0.5438120244462241
# Angular Displacement (AD) in radian: 0.0374024411684724  Angular Displacement (AD) in degrees: 2.143002022439827
# Angular Displacement (AD) in radian: 0.0432091781391752  Angular Displacement (AD) in degrees: 2.4757035436036796
# Angular Displacement (AD) in radian: 0.00879051749424099  Angular Displacement (AD) in degrees: 0.5036595521559246
# Angular Displacement (AD) in radian: 0.0566121153009239  Angular Displacement (AD) in degrees: 3.2436352760509313
# Angular Displacement (AD) in radian: 0.0344651508422780  Angular Displacement (AD) in degrees: 1.9747076835442852
# Angular Displacement (AD) in radian: 0.0170984571960142  Angular Displacement (AD) in degrees: 0.9796694335167058
# Angular Displacement (AD) in radian: 0.0478730410425444  Angular Displacement (AD) in degrees: 2.742923204194362
# Angular Displacement (AD) in radian: 0.0159599997881577  Angular Displacement (AD) in degrees: 0.9144406288911249
# Angular Displacement (AD) in radian: 0.123472930284906  Angular Displacement (AD) in degrees: 7.07447778943817
# Angular Displacement (AD) in radian: 0.0616021520837692  Angular Displacement (AD) in degrees: 3.529543323323005
# Angular Displacement (AD) in radian: 0.0442530127266513  Angular Displacement (AD) in degrees: 2.5355108599758407
# Angular Displacement (AD) in radian: 0.0507040431016373  Angular Displacement (AD) in degrees: 2.905127673973233
# Angular Displacement (AD) in radian: 0.0617228812034999  Angular Displacement (AD) in degrees: 3.536460592347901
# Angular Displacement (AD) in radian: 0.0231825507485827  Angular Displacement (AD) in degrees: 1.3282623162416347
# Angular Displacement (AD) in radian: 0.0457927478665719  Angular Displacement (AD) in degrees: 2.6237311850612732
# Angular Displacement (AD) in radian: 0.0301850586174235  Angular Displacement (AD) in degrees: 1.7294764631333635
# Angular Displacement (AD) in radian: 0.123038266299524  Angular Displacement (AD) in degrees: 7.049573377569412
# Angular Displacement (AD) in radian: 0.0265469075534614  Angular Displacement (AD) in degrees: 1.5210257619373035
# Angular Displacement (AD) in radian: 0.0800214371114941  Angular Displacement (AD) in degrees: 4.584890617060149
# Angular Displacement (AD) in radian: 0.183154705935043  Angular Displacement (AD) in degrees: 10.493991648037662
# Angular Displacement (AD) in radian: 0.0241059552386748  Angular Displacement (AD) in degrees: 1.3811694963073406
# Angular Displacement (AD) in radian: 0.0407154912214314  Angular Displacement (AD) in degrees: 2.3328258077899706
# Angular Displacement (AD) in radian: 0.0966999649816070  Angular Displacement (AD) in degrees: 5.540499872508939
# Angular Displacement (AD) in radian: 0.0323167763152278  Angular Displacement (AD) in degrees: 1.8516148903308935
# Angular Displacement (AD) in radian: 0.0439430456505924  Angular Displacement (AD) in degrees: 2.5177510547296507
# Angular Displacement (AD) in radian: 0.0478623428127300  Angular Displacement (AD) in degrees: 2.7423102407777376
# Angular Displacement (AD) in radian: 0.158221900548119  Angular Displacement (AD) in degrees: 9.065447127945875
# Angular Displacement (AD) in radian: 0.0363604312110765  Angular Displacement (AD) in degrees: 2.0832992496704343
# Angular Displacement (AD) in radian: 0.0180993362241420  Angular Displacement (AD) in degrees: 1.0370155776315855
# Angular Displacement (AD) in radian: 0.0409230430587912  Angular Displacement (AD) in degrees: 2.344717652100875
# Angular Displacement (AD) in radian: 0.0353076449209709  Angular Displacement (AD) in degrees: 2.022979038518147
# Angular Displacement (AD) in radian: 0.0229292854353143  Angular Displacement (AD) in degrees: 1.3137512826942983
# Angular Displacement (AD) in radian: 0.0157328726134807  Angular Displacement (AD) in degrees: 0.9014272003694026
# Angular Displacement (AD) in radian: 0.0179407722445651  Angular Displacement (AD) in degrees: 1.0279305308190312
# Angular Displacement (AD) in radian: 0.0535903032976534  Angular Displacement (AD) in degrees: 3.0704982017815565
# Angular Displacement (AD) in radian: 0.0181148598295010  Angular Displacement (AD) in degrees: 1.0379050147014786
# Angular Displacement (AD) in radian: 0.0179405263186395  Angular Displacement (AD) in degrees: 1.0279164403014198
# Angular Displacement (AD) in radian: 0.0110938736450277  Angular Displacement (AD) in degrees: 0.6356321383115003
# Angular Displacement (AD) in radian: 0.0172263068844348  Angular Displacement (AD) in degrees: 0.9869946810752676
# Angular Displacement (AD) in radian: 0.00530009247548990  Angular Displacement (AD) in degrees: 0.3036729298746162
# Angular Displacement (AD) in radian: 0.103601956913150  Angular Displacement (AD) in degrees: 5.935954880419683
# Angular Displacement (AD) in radian: 0.0524754540707431  Angular Displacement (AD) in degrees: 3.0066220462861732
# Angular Displacement (AD) in radian: 0.0859559698660237  Angular Displacement (AD) in degrees: 4.92491429727684
# Angular Displacement (AD) in radian: 0.0442621292292707  Angular Displacement (AD) in degrees: 2.5360331970998504
# Angular Displacement (AD) in radian: 0.0238045943420688  Angular Displacement (AD) in degrees: 1.3639027888215403
# Angular Displacement (AD) in radian: 0.0423702491831147  Angular Displacement (AD) in degrees: 2.427636455110095
# Angular Displacement (AD) in radian: 0.00971233461600134  Angular Displacement (AD) in degrees: 0.5564757827156901
# Angular Displacement (AD) in radian: 0.0188780226769089  Angular Displacement (AD) in degrees: 1.0816310249391414
# Angular Displacement (AD) in radian: 0.0520511647221761  Angular Displacement (AD) in degrees: 2.9823120573209296
# Angular Displacement (AD) in radian: 0.470149336667064  Angular Displacement (AD) in degrees: 26.937572731898026
# Angular Displacement (AD) in radian: 0.0213588808690697  Angular Displacement (AD) in degrees: 1.2237737289204091
# Angular Displacement (AD) in radian: 0.0216466683161734  Angular Displacement (AD) in degrees: 1.2402627350362962
# Angular Displacement (AD) in radian: 0.0349573887728972  Angular Displacement (AD) in degrees: 2.0029108394850166
# Angular Displacement (AD) in radian: 0.0265194588975720  Angular Displacement (AD) in degrees: 1.519453069801536
# Angular Displacement (AD) in radian: 0.0134477297832352  Angular Displacement (AD) in degrees: 0.7704981606117539
# Angular Displacement (AD) in radian: 0.0351604185134417  Angular Displacement (AD) in degrees: 2.014543586733852
# Angular Displacement (AD) in radian: 0.00891049913077775  Angular Displacement (AD) in degrees: 0.5105339935485536
# Angular Displacement (AD) in radian: 0.0449534541738882  Angular Displacement (AD) in degrees: 2.5756431986985477
# Angular Displacement (AD) in radian: 0.0791356275440221  Angular Displacement (AD) in degrees: 4.534137467391693
# Angular Displacement (AD) in radian: 0.0119831060809221  Angular Displacement (AD) in degrees: 0.6865814038943906
# Angular Displacement (AD) in radian: 0.00782975855484339  Angular Displacement (AD) in degrees: 0.4486121197989772
# Angular Displacement (AD) in radian: 0.199195774819662  Angular Displacement (AD) in degrees: 11.413077194004979
# Angular Displacement (AD) in radian: 0.0203332486022351  Angular Displacement (AD) in degrees: 1.1650093286983496
# Angular Displacement (AD) in radian: 0  Angular Displacement (AD) in degrees: 0.0
#
# -----------------------Final mean Angular Displacement (mAD)---------------------------
#
# mAD in radians: 0.0405239019335242  mAD in degrees: 2.3218485501929718
# std. AD in radians: 0.06386324953714509  median AD in radians: 0.0253001727630494

# %% [markdown]
# ## Tool tip Evaluation Eculedian Distance

# %%
PredictionPath = '/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/Jupyter/Results/'
Prediction = glob.glob(PredictionPath+"*.png")
Prediction.sort()
# print(len(Prediction))

OriginaltipGT = glob.glob('/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Test_Positive_TipPoint/'+"*.png")
OriginaltipGT.sort()
# print(len(OriginaltipGT))

OriginalImage = glob.glob('/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Test_Positive/'+"*.png")
OriginalImage.sort()
# print(len(OriginalImage))

tipsavePath = '/home/mahmoud/Desktop/laparoscopic-Tools-Segmentation/DataFinal/Test/Results_Evaluation/Tip/'

i=0

Euclidean_Tip=[]

for Pred in Prediction:
    
    filename, file_extension = os.path.splitext(Pred) 

    if 'tip' in filename:
        #--------------------------Read the Prediction from SIMO----------------------------------
        imgPred = cv2.imread(Pred,0)
        temp = imgPred.copy()
        
        #-------------------------Read Original Image with TIP GT---------------------------------
        orimg = cv2.imread(OriginalImage[i],-1)
        orimg = cv2.resize(orimg,(256,192))
        
        truepoint = cv2.imread(OriginaltipGT[i],0)
        truepoint = cv2.resize(truepoint,(256,192))
        i=i+1

        #----------------------Truncate the intensity lower than Threshold-----------------------
        Threshold = (imgPred.max())-100
        imgPred[imgPred<Threshold]=0
               
#         savelinePath=tipsavePath+filename[-7:]+'_Pred_.png'
#         cv2.imwrite(savelinePath,imgPred)
        
        #-----------------------Overlay with original Image--------------------------------------       
        temp = cv2.merge((imgPred, imgPred, imgPred))
        temp [:,:,0]=0
        temp [:,:,2]=0   
        
        temp2 = cv2.merge((truepoint, truepoint, truepoint))
        temp2 [:,:,0]=0

        dummy = cv2.addWeighted(temp, 0.8, orimg, 0.8, 0)
        dummy = cv2.addWeighted(temp2, 0.8, dummy, 0.8, 0)
        
                
        #------------------------Euclidean Distance-----------------------------------------------
        XY_PredictedPoint = np.argwhere(imgPred.max() == imgPred)
        XY_truePoint = np.argwhere(truepoint.max() == truepoint)
        
        X_P = XY_PredictedPoint[0][1]
        Y_P = XY_PredictedPoint[0][0]
        
        X_G = XY_truePoint[0][1]
        Y_G = XY_truePoint[0][0]  

        euclidean_distance = distance.euclidean((X_P, Y_P), (X_G, Y_G))
        print('ImageID: '+ filename[-7:-4]+ '.   Euclidean Distance in pixels: '+ str(euclidean_distance))
        Euclidean_Tip.append(euclidean_distance)
        
        #--------------------Approximate point with True point---------------------------------------
        
        font                   = cv2.FONT_HERSHEY_SIMPLEX
        bottomLeftCornerOfText = (80,185)
        fontScale              = 1
        fontColor              = (255,255,255)
        lineType               = 2

        cv2.putText(dummy,str(round(euclidean_distance,2)), 
            bottomLeftCornerOfText, 
            font, 
            fontScale,
            fontColor,
            lineType)

        savelinePath=tipsavePath+'ImgID_'+filename[-12:]+'_Overlay_Pred_True.png'
        cv2.imwrite(savelinePath,dummy)  

        
print()
print('-----------------------Final Mean Euclidean Distance (mED)---------------------------')
print()
print('Mean Euclidean Distance (mED) in pixels: '+ str(np.mean(Euclidean_Tip)))
print('std. Euclidean Distance (ED): '+ str(math.sqrt(np.mean((np.array(Euclidean_Tip)-np.mean(Euclidean_Tip))**2))) 
      + '  median Euclidean Distance (ED): ' + str(np.median(Euclidean_Tip)))
# Out:
# ImageID: ipP.   Euclidean Distance in pixels: 40.8166632639171
# ImageID: ipP.   Euclidean Distance in pixels: 5.0990195135927845
# ImageID: ipP.   Euclidean Distance in pixels: 15.231546211727817
# ImageID: ipP.   Euclidean Distance in pixels: 9.486832980505138
# ImageID: ipP.   Euclidean Distance in pixels: 7.0710678118654755
# ImageID: ipP.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 6.0
# ImageID: ipP.   Euclidean Distance in pixels: 3.605551275463989
# ImageID: ipP.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: ipP.   Euclidean Distance in pixels: 48.41487374764082
# ImageID: ipP.   Euclidean Distance in pixels: 31.38470965295043
# ImageID: ipP.   Euclidean Distance in pixels: 26.832815729997478
# ImageID: ipP.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: ipP.   Euclidean Distance in pixels: 5.385164807134504
# ImageID: ipP.   Euclidean Distance in pixels: 126.65701717630967
# ImageID: ipP.   Euclidean Distance in pixels: 22.825424421026653
# ImageID: ipP.   Euclidean Distance in pixels: 38.91015291668744
# ImageID: ipP.   Euclidean Distance in pixels: 44.77722635447622
# ImageID: ipP.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: ipP.   Euclidean Distance in pixels: 18.973665961010276
# ImageID: ipP.   Euclidean Distance in pixels: 9.219544457292887
# ImageID: ipP.   Euclidean Distance in pixels: 46.51881339845203
# ImageID: ipP.   Euclidean Distance in pixels: 8.246211251235321
# ImageID: ipP.   Euclidean Distance in pixels: 32.0624390837628
# ImageID: ipP.   Euclidean Distance in pixels: 23.430749027719962
# ImageID: ipP.   Euclidean Distance in pixels: 49.39635614091387
# ImageID: ipP.   Euclidean Distance in pixels: 2.0
# ImageID: ipP.   Euclidean Distance in pixels: 3.0
# ImageID: ipP.   Euclidean Distance in pixels: 5.0
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 26.68332812825267
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 47.43416490252569
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 12.041594578792296
# ImageID: ipP.   Euclidean Distance in pixels: 2.0
# ImageID: ipP.   Euclidean Distance in pixels: 7.280109889280518
# ImageID: ipP.   Euclidean Distance in pixels: 9.0
# ImageID: ipP.   Euclidean Distance in pixels: 2.0
# ImageID: ipP.   Euclidean Distance in pixels: 5.0990195135927845
# ImageID: ipP.   Euclidean Distance in pixels: 6.708203932499369
# ImageID: ipP.   Euclidean Distance in pixels: 4.0
# ImageID: ipP.   Euclidean Distance in pixels: 33.24154027718932
# ImageID: ipP.   Euclidean Distance in pixels: 56.142675390472796
# ImageID: ipP.   Euclidean Distance in pixels: 19.026297590440446
# ImageID: ipP.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 4.0
# ImageID: ipP.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: ipP.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 7.810249675906654
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 91.54780172128658
# ImageID: ipP.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: ipP.   Euclidean Distance in pixels: 9.219544457292887
# ImageID: ipP.   Euclidean Distance in pixels: 13.038404810405298
# ImageID: ipP.   Euclidean Distance in pixels: 2.8284271247461903
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 13.0
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: ipP.   Euclidean Distance in pixels: 7.615773105863909
# ImageID: ipP.   Euclidean Distance in pixels: 54.08326913195984
# ImageID: ipP.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: ipP.   Euclidean Distance in pixels: 29.732137494637012
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 23.323807579381203
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 3.0
# ImageID: ipP.   Euclidean Distance in pixels: 37.64306044943742
# ImageID: ipP.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: ipP.   Euclidean Distance in pixels: 6.708203932499369
# ImageID: ipP.   Euclidean Distance in pixels: 2.0
# ImageID: ipP.   Euclidean Distance in pixels: 3.605551275463989
# ImageID: ipP.   Euclidean Distance in pixels: 4.47213595499958
# ImageID: ipP.   Euclidean Distance in pixels: 6.0
# ImageID: ipP.   Euclidean Distance in pixels: 113.3225485064645
# ImageID: ipP.   Euclidean Distance in pixels: 4.0
# ImageID: ipP.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: ipP.   Euclidean Distance in pixels: 0.0
# ImageID: ipP.   Euclidean Distance in pixels: 53.46026561849464
# ImageID: ipP.   Euclidean Distance in pixels: 16.278820596099706
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 2.0
# ImageID: ipP.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: ipP.   Euclidean Distance in pixels: 13.038404810405298
# ImageID: ipP.   Euclidean Distance in pixels: 31.38470965295043
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 6.0
# ImageID: ipP.   Euclidean Distance in pixels: 2.0
# ImageID: ipP.   Euclidean Distance in pixels: 2.0
# ImageID: ipP.   Euclidean Distance in pixels: 4.47213595499958
# ImageID: ipP.   Euclidean Distance in pixels: 43.86342439892262
# ImageID: ipP.   Euclidean Distance in pixels: 13.038404810405298
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 15.231546211727817
# ImageID: ipP.   Euclidean Distance in pixels: 11.0
# ImageID: ipP.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: ipP.   Euclidean Distance in pixels: 6.082762530298219
# ImageID: ipP.   Euclidean Distance in pixels: 5.0
# ImageID: ipP.   Euclidean Distance in pixels: 81.12336284942828
# ImageID: ipP.   Euclidean Distance in pixels: 13.152946437965905
# ImageID: ipP.   Euclidean Distance in pixels: 5.0990195135927845
# ImageID: ipP.   Euclidean Distance in pixels: 78.08969202141856
# ImageID: ipP.   Euclidean Distance in pixels: 5.0990195135927845
# ImageID: ipP.   Euclidean Distance in pixels: 5.385164807134504
# ImageID: ipP.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: ipP.   Euclidean Distance in pixels: 6.4031242374328485
# ImageID: ipP.   Euclidean Distance in pixels: 4.47213595499958
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 7.0710678118654755
# ImageID: ipP.   Euclidean Distance in pixels: 7.211102550927978
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 5.385164807134504
# ImageID: ipP.   Euclidean Distance in pixels: 1.0
# ImageID: ipP.   Euclidean Distance in pixels: 15.652475842498529
# ImageID: ipP.   Euclidean Distance in pixels: 7.810249675906654
# ImageID: ipP.   Euclidean Distance in pixels: 3.0
# ImageID: ipP.   Euclidean Distance in pixels: 4.47213595499958
# ImageID: ipP.   Euclidean Distance in pixels: 13.601470508735444
# ImageID: ipP.   Euclidean Distance in pixels: 24.020824298928627
# ImageID: ipP.   Euclidean Distance in pixels: 42.20189569201838
# ImageID: ipP.   Euclidean Distance in pixels: 49.64876634922564
# ImageID: ipP.   Euclidean Distance in pixels: 24.041630560342615
# ImageID: ipP.   Euclidean Distance in pixels: 3.605551275463989
# ImageID: ipP.   Euclidean Distance in pixels: 31.38470965295043
# ImageID: ipP.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: ipP.   Euclidean Distance in pixels: 18.027756377319946
# ImageID: ipP.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: ipP.   Euclidean Distance in pixels: 79.47955712005447
# ImageID: ipP.   Euclidean Distance in pixels: 25.079872407968907
# ImageID: ipP.   Euclidean Distance in pixels: 99.32774033471213
# ImageID: ipP.   Euclidean Distance in pixels: 19.026297590440446
# ImageID: ipP.   Euclidean Distance in pixels: 52.773099207835045
# ImageID: ipP.   Euclidean Distance in pixels: 34.88552708502482
# ImageID: ipP.   Euclidean Distance in pixels: 90.82400563727631
# ImageID: ipP.   Euclidean Distance in pixels: 48.373546489791295
# ImageID: ipP.   Euclidean Distance in pixels: 58.52349955359813
# ImageID: ipP.   Euclidean Distance in pixels: 95.77577981932593
# ImageID: ipP.   Euclidean Distance in pixels: 78.40918313565064
# ImageID: ipP.   Euclidean Distance in pixels: 49.64876634922564
# ImageID: ipP.   Euclidean Distance in pixels: 110.3675676999362
# ImageID: ipP.   Euclidean Distance in pixels: 28.160255680657446
# ImageID: ipP.   Euclidean Distance in pixels: 13.152946437965905
# ImageID: ipP.   Euclidean Distance in pixels: 51.62363799656123
# ImageID: ipP.   Euclidean Distance in pixels: 8.06225774829855
#
# -----------------------Final Mean Euclidean Distance (mED)---------------------------
#
# Mean Euclidean Distance (mED) in pixels: 19.495004035747453
# std. Euclidean Distance (ED): 26.287311382568443  median Euclidean Distance (ED): 6.708203932499369
